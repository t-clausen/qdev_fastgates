# %% [markdown]
# $$\int_{t_0}^{t_0+t_g}dt\xi(t)\cos(\omega_dt)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dt\left(1-\cos\left(\frac{2n\pi}{t_g}(t-t_0)\right)\right)\cos(\omega_dt)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dt\left(\cos(\omega_dt)-\cos\left(\frac{2n\pi t}{t_g}\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)\cos(\omega_dt)-\sin\left(\frac{2n\pi t}{t_g}\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)\cos(\omega_dt)\right)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dt\left(\cos(\omega_dt)-\frac12\cos\left(\left[\frac{2n\pi}{t_g}-\omega_d\right]t\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\cos\left(\left[\frac{2n\pi}{t_g}+\omega_d\right]t\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\sin\left(\left[\frac{2n\pi}{t_g}-\omega_d\right]t\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\sin\left(\left[\frac{2n\pi}{t_g}+\omega_d\right]t\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)\right)$$

# %% [markdown]
# $$\Rightarrow\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dt$$
# $$[1+\cos(2\omega_dt)]\sigma_x+\sin(2\omega_dt)\sigma_y$$
# $$-\cos\left(\frac{2n\pi t_0}{t_g}\right)\left[\cos\left(\left[\frac{2n\pi}{t_g}-2\omega_d\right]t\right)+\cos\left(\frac{2n\pi}{t_g}t\right)\right]\sigma_x-\cos\left(\frac{2n\pi t_0}{t_g}\right)\left[\sin\left(\left[\frac{2n\pi}{t_g}-2\omega_d\right]t\right)+\sin\left(\frac{2n\pi}{t_g}t\right)\right]\sigma_y$$
# $$-\sin\left(\frac{2n\pi t_0}{t_g}\right)\left[\sin\left(\left[\frac{2n\pi}{t_g}-2\omega_d\right]t\right)+\sin\left(\frac{2n\pi}{t_g}t\right)\right]\sigma_x-\sin\left(\frac{2n\pi t_0}{t_g}\right)\left[\cos\left(\left[\frac{2n\pi}{t_g}-2\omega_d\right]t\right)+\cos\left(\frac{2n\pi}{t_g}t\right)\right]\sigma_y$$

# %% [markdown]
# $$\int_{t_0}^{t_0+t_g}dte^{-i2\pi ft}\xi(t)\cos(\omega_dt)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dte^{-i2\pi ft}\left(1-\cos\left(\frac{2n\pi}{t_g}(t-t_0)\right)\right)\cos(\omega_dt)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dte^{-i2\pi ft}\left(\cos(\omega_dt)-\cos\left(\frac{2n\pi t}{t_g}\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)\cos(\omega_dt)-\sin\left(\frac{2n\pi t}{t_g}\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)\cos(\omega_dt)\right)$$
# $$=\sum_{n=1}c_n\int_{t_0}^{t_0+t_g}dte^{-i2\pi ft}\left(\cos(\omega_dt)-\frac12\cos\left(\left[\frac{2n\pi}{t_g}-\omega_d\right]t\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\cos\left(\left[\frac{2n\pi}{t_g}+\omega_d\right]t\right)\cos\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\sin\left(\left[\frac{2n\pi}{t_g}-\omega_d\right]t\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)-\frac12\sin\left(\left[\frac{2n\pi}{t_g}+\omega_d\right]t\right)\sin\left(\frac{2n\pi t_0}{t_g}\right)\right)$$

# %%
import math
import sympy as sp
t_g, n, t_0, omega_d = sp.symbols('t_g n t_0 omega_d')
t__g = t_g
t__0 = t_0
omega__d = omega_d
expr = (-16 * sp.cos(2 * sp.pi * n * t__0 / t__g) * sp.pi ** 2 * n ** 2 * omega__d * (sp.cos(2 * t__0 * omega__d) / 2 + 0.1e1 / 0.2e1) * sp.sin(2 * sp.pi * n * t__0 / t__g) - 8 * (0.1e1 / 0.2e1 + sp.cos(2 * sp.pi * n * t__0 / t__g) / 2) * sp.pi * n * t__g * omega__d ** 2 * sp.cos(t__0 * omega__d) * sp.sin(t__0 * omega__d) - 8 * sp.pi ** 2 * n ** 2 * (0.1e1 / 0.2e1 - sp.sin(2 * sp.pi * n * t__0 / t__g) / 2) * sp.cos(t__0 * omega__d) * sp.sin(t__0 * omega__d) * omega__d + 8 * (0.1e1 / 0.2e1 + sp.cos(2 * sp.pi * n * t__0 / t__g) / 2) * sp.pi ** 2 * n ** 2 * sp.cos(t__0 * omega__d) * sp.sin(t__0 * omega__d) * omega__d - 4 * sp.cos(2 * sp.pi * n * t__0 / t__g) * sp.sin(2 * sp.pi * n * t__0 / t__g) * sp.pi * omega__d ** 2 * (0.1e1 / 0.2e1 - sp.sin(t__0 * omega__d) / 2) * n * t__g + 4 * sp.cos(2 * sp.pi * n * t__0 / t__g) * sp.sin(2 * sp.pi * n * t__0 / t__g) * sp.pi * (sp.cos(2 * t__0 * omega__d) / 2 + 0.1e1 / 0.2e1) * omega__d ** 2 * n * t__g + 4 * sp.cos(t__0 * omega__d) * sp.pi * n * t__g * omega__d ** 2 * sp.sin(t__0 * omega__d) + 8 * sp.cos(2 * sp.pi * n * t__0 / t__g) * t__g * omega__d ** 2 * sp.pi * n * sp.sin(2 * sp.pi * n * t__0 / t__g) - 2 * sp.pi ** 2 * omega__d * sp.sin((t__0 + t__g) * omega__d) * n ** 2 + 2 * sp.pi ** 2 * omega__d * sp.sin(t__0 * omega__d) * n ** 2 + 2 * sp.pi * omega__d ** 2 * sp.sin((t__0 + t__g) * omega__d) * n * t__g + 4 * sp.pi ** 2 * n ** 2 * omega__d * sp.sin(2 * sp.pi * n * (t__g + 2 * t__0) / t__g) + 2 * sp.pi * n * omega__d * (2 * sp.pi * n - t__g * omega__d) * sp.sin(2 * (2 * sp.pi * n * t__0 + sp.pi * n * t__g - t__0 * omega__d * t__g - omega__d * t__g ** 2) / t__g) - 2 * sp.pi * omega__d ** 2 * sp.sin(t__0 * omega__d) * n * t__g - 4 * t__g * omega__d ** 2 * sp.pi * n * sp.sin(2 * sp.pi * n * (t__g + 2 * t__0) / t__g)) ** 2 / sp.pi ** 2 / n ** 2 / (sp.pi * n - t__g * omega__d) ** 2 / omega__d ** 2 / 4
expr = sp.trigsimp(expr)
#expr = sp.expand_trig(expr)
expr = expr.subs(sp.cos(sp.pi*n*t_0/t_g)**2, 0.5 + 0.5*sp.cos(2*sp.pi*n*t_0/t_g))
expr = expr.subs(sp.sin(omega_d*t_0)*sp.cos(omega_d*t_0), 0.5*sp.sin(2*omega_d*t_0))
expr = sp.trigsimp(expr)
expr = expr.subs(sp.sin(omega_d*t_0)*sp.sin(2*omega_d*t_0), 0.5*sp.cos(omega_d*t_0) - 0.5*sp.cos(3*omega_d*t_0))
expr = sp.trigsimp(expr)
expr = expr.subs(sp.sin(omega_d*t_0)*sp.sin(2*sp.pi*n*t_0/t_g), 0.5*sp.cos((omega_d-2*sp.pi*n/t_g)*t_0) - 0.5*sp.cos((omega_d+2*sp.pi*n/t_g)*t_0))
expr = sp.trigsimp(expr)
expr = expr.subs(sp.sin(omega_d*t_0)*sp.sin(omega_d*(t_0+t_g)), 0.5*sp.cos(omega_d*t_g) - 0.5*sp.cos(2*omega_d*t_0 + omega_d*t_g))
expr = sp.trigsimp(expr)
expr
# Out:
# (-4.0*pi**2*n**2*omega_d*(0.5 - 0.5*sin(2*pi*n*t_0/t_g))*sin(2*omega_d*t_0) + 2*pi**2*n**2*omega_d*sin(omega_d*t_0) + 4.0*pi**2*n**2*omega_d*sin(2*omega_d*t_0)*cos(pi*n*t_0/t_g)**2 - 2*pi**2*n**2*omega_d*sin(omega_d*(t_0 + t_g)) - 16.0*pi**2*n**2*omega_d*sin(2*pi*n*t_0/t_g)*cos(omega_d*t_0)**2*cos(2*pi*n*t_0/t_g) + 4*pi**2*n**2*omega_d*sin(2*pi*n*(2*t_0 + t_g)/t_g) - 4*pi*n*omega_d**2*t_g*(0.5 - 0.5*sin(omega_d*t_0))*sin(2*pi*n*t_0/t_g)*cos(2*pi*n*t_0/t_g) - 2*pi*n*omega_d**2*t_g*sin(omega_d*t_0) - 4.0*pi*n*omega_d**2*t_g*sin(2*omega_d*t_0)*cos(pi*n*t_0/t_g)**2 + 2*pi*n*omega_d**2*t_g*sin(2*omega_d*t_0) + 2*pi*n*omega_d**2*t_g*sin(omega_d*(t_0 + t_g)) + 4.0*pi*n*omega_d**2*t_g*sin(2*pi*n*t_0/t_g)*cos(omega_d*t_0)**2*cos(2*pi*n*t_0/t_g) + 4*pi*n*omega_d**2*t_g*sin(4*pi*n*t_0/t_g) - 4*pi*n*omega_d**2*t_g*sin(2*pi*n*(2*t_0 + t_g)/t_g) + 2*pi*n*omega_d*(2*pi*n - omega_d*t_g)*sin(2*(2*pi*n*t_0/t_g + pi*n - omega_d*t_0 - omega_d*t_g)))**2/(4*pi**2*n**2*omega_d**2*(pi*n - omega_d*t_g)**2)
